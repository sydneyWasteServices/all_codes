# %%
import pandas as pd
import numpy as np

# %%
PATH = "C:\\Users\\User\\Desktop\\blob_storage\\waste_report\\Sept2021.csv"
df = pd.read_csv(PATH)
df
# Out:
#      Customer_Number      Waste_type           Address_1 STATE  Total_volume  \
# 0               1345   General Waste  100 Bayswater Road   NSW          2.20
# 1               1345   General Waste  100 Bayswater Road   NSW          2.20
# 2               1345   General Waste  100 Bayswater Road   NSW          3.30
# 3               1345        Comingle  100 Bayswater Road   NSW          1.10
# 4               1345   General Waste  100 Bayswater Road   NSW          2.20
# ..               ...             ...                 ...   ...           ...
# 527             4547   General Waste   280 George Street   NSW          0.66
# 528             4581   General Waste        99 City Road   VIC          0.66
# 529             4581   General Waste        99 City Road   VIC          0.66
# 530             4615  Security Paper    19 Market Street   NSW          0.24
# 531             4615  Security Paper    19 Market Street   NSW          0.48
#
#      Total_price
# 0          56.39
# ...

# %%
df[df.Customer_Number.eq(4615)]
# Out:
#      Customer_Number      Waste_type         Address_1 STATE  Total_volume  \
# 530             4615  Security Paper  19 Market Street   NSW          0.24
# 531             4615  Security Paper  19 Market Street   NSW          0.48
#
#      Total_price
# 530         38.5
# 531         77.0

# %%
summary_df = df.groupby('Waste_type')['Total_price','Total_volume'].sum()

summary_df
# Out:
# <ipython-input-9-5304c3d5e9ab>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   summary_df = df.groupby('Waste_type')['Total_price','Total_volume'].sum()
#                 Total_price  Total_volume
# Waste_type
# Cardboard            826.20        132.00
# Comingle            4753.16        211.76
# General Waste      19908.12        603.36
# Organics              43.98          0.48
# Security Paper       393.96          2.16
