# %%
import pandas as pd
import numpy as np

# %%
PATH = "C:\\Users\\User\\Desktop\\blob_storage\\fuel_we\\RouteSummariesDetail_011121_31372220.xlsx"
df = pd.read_excel(PATH)
# df.RouteDate = pd.to_datetime(df.RouteDate, format="%d/%m/%y")

# %%
df
# Out:
#       RouteNumber RouteDate          RouteDescription TruckNumber  \
# 0           RED-4  01/09/16                     RED-4         RED
# 1           RL4-4  01/09/16                     RL4-4         RL4
# 2           RL5-4  01/09/16                     RL5-4         RL5
# 3           RL9-4  01/09/16                     RL9-4         RL9
# 4           RLD-4  01/09/16                     RLD-4         RLD
# ...           ...       ...                       ...         ...
# 63039       SWG-1  01/11/21                     SWG-1      XN72MK
# 63040     UOSGW-1  01/11/21  Sydney Uni GW Monday Run      XN76VB
# 63041       VEO-1  01/11/21                     VEO-1         VEO
# 63042    VEOACT-1  01/11/21               Veolia  ACT         SUB
# 63043       VTG-1  01/11/21                       VTG         SUB
#
#               Driver StartTime EndTime  NormalLabourHrs  OverTimeLabourHrs  \
# 0                NaN       NaN     NaN              0.0                  0
# 1        Johnny Ruhr       NaN     NaN              0.0                  0
# 2                NaN       NaN     NaN              0.0                  0
# 3                NaN       NaN     NaN              0.0                  0
# 4                NaN       NaN     NaN              0.0                  0
# ...              ...       ...     ...              ...                ...
# 63039    Ben Edwards  02:45:21     NaN              0.0                  0
# 63040  Nathan Bracey  04:22:30     NaN              0.0                  0
# 63041         Veolia       NaN     NaN              0.0                  0
# 63042  Subcontractor       NaN     NaN              0.0                  0
# 63043  Subcontractor       NaN     NaN              0.0                  0
#
#        LabourCostOverTime2  ...  FuelCost  TipCharges  BookingCharges  \
# 0                        0  ...       0.0         0.0            0.00
# 1                        0  ...       0.0         0.0            0.00
# 2                        0  ...       0.0         0.0            0.00
# 3                        0  ...       0.0         0.0            0.00
# 4                        0  ...       0.0         0.0            0.00
# ...                    ...  ...       ...         ...             ...
# 63039                    0  ...       0.0         0.0         1913.89
# 63040                    0  ...       0.0         0.0         2098.60
# 63041                    0  ...       0.0         0.0            0.00
# 63042                    0  ...       0.0         0.0            0.00
# 63043                    0  ...       0.0         0.0            0.00
#
#        AdditionalCharges  TotalRevenue  GrossMarigin  Distance  TotalCost  \
# 0                    0.0          0.00          0.00         0        0.0
# 1                    0.0          0.00          0.00         0        0.0
# 2                    0.0          0.00          0.00         0        0.0
# 3                    0.0          0.00          0.00         0        0.0
# 4                    0.0          0.00          0.00         0        0.0
# ...                  ...           ...           ...       ...        ...
# 63039                0.0       1913.89       1913.89        -2        0.0
# 63040                0.0       2098.60       2098.60        -2        0.0
# 63041                0.0          0.00          0.00         0        0.0
# 63042                0.0          0.00          0.00         0        0.0
# 63043                0.0          0.00          0.00         0        0.0
#
#        Branch  ServCode
# 0         NaN        RL
# 1         NaN        RL
# 2         NaN        RL
# 3         NaN        RL
# 4         NaN        RL
# ...       ...       ...
# 63039     NaN        RL
# 63040     NaN        RL
# 63041     NaN        RL
# 63042     NaN        RL
# 63043     NaN        RL
#
# [63044 rows x 38 columns]

# %%
df[df.RouteDate.between('20210901', '20211101')]
# Out:
#       RouteNumber  RouteDate          RouteDescription TruckNumber  \
# 60480    ALLMED-3 2021-09-01                  ALLMED-3      ALLMED
# 60481   AUSSKIP-3 2021-09-01                 AUSSKIP-3           0
# 60482       BIN-3 2021-09-01                     BIN-3      CV50EC
# 60483       BR1-3 2021-09-01                     BR1-3      XN75OS
# 60484       BR2-3 2021-09-01                     BR2-3      CJ65PS
# ...           ...        ...                       ...         ...
# 63039       SWG-1 2021-11-01                     SWG-1      XN72MK
# 63040     UOSGW-1 2021-11-01  Sydney Uni GW Monday Run      XN76VB
# 63041       VEO-1 2021-11-01                     VEO-1         VEO
# 63042    VEOACT-1 2021-11-01               Veolia  ACT         SUB
# 63043       VTG-1 2021-11-01                       VTG         SUB
#
#                 Driver StartTime   EndTime  NormalLabourHrs  \
# 60480    Subcontractor       NaN       NaN              0.0
# 60481    Subcontractor       NaN       NaN              0.0
# 60482     Bin Delivery  09:05:06       NaN              0.0
# 60483  Andrew Peterson  23:04:53       NaN              0.0
# 60484       Paul Nevin  16:54:32  01:30:25              8.6
# ...                ...       ...       ...              ...
# 63039      Ben Edwards  02:45:21       NaN              0.0
# 63040    Nathan Bracey  04:22:30       NaN              0.0
# 63041           Veolia       NaN       NaN              0.0
# 63042    Subcontractor       NaN       NaN              0.0
# 63043    Subcontractor       NaN       NaN              0.0
#
#        OverTimeLabourHrs  LabourCostOverTime2  ...  FuelCost  TipCharges  \
# 60480                  0                    0  ...       0.0         0.0
# 60481                  0                    0  ...       0.0         0.0
# 60482                  0                    0  ...       0.0         0.0
# 60483                  0                    0  ...       0.0         0.0
# 60484                  0                    0  ...      42.0         0.0
# ...                  ...                  ...  ...       ...         ...
# 63039                  0                    0  ...       0.0         0.0
# 63040                  0                    0  ...       0.0         0.0
# 63041                  0                    0  ...       0.0         0.0
# 63042                  0                    0  ...       0.0         0.0
# 63043                  0                    0  ...       0.0         0.0
#
#        BookingCharges  AdditionalCharges  TotalRevenue  GrossMarigin  \
# 60480          126.84                0.0        126.84        126.84
# 60481          244.12                0.0        244.12        244.12
# 60482            0.00                0.0          0.00          0.00
# 60483         1313.00                0.0       1313.00       1311.72
# 60484         1823.23                0.0       1823.23       1778.35
# ...               ...                ...           ...           ...
# 63039         1913.89                0.0       1913.89       1913.89
# 63040         2098.60                0.0       2098.60       2098.60
# 63041            0.00                0.0          0.00          0.00
# 63042            0.00                0.0          0.00          0.00
# 63043            0.00                0.0          0.00          0.00
#
#        Distance  TotalCost  Branch  ServCode
# 60480         0       0.00     NaN        RL
# 60481         0       0.00     NaN        FL
# 60482        -2       0.00     NaN        RL
# 60483        -2       1.28     NaN        RL
# 60484         0      44.88     NaN        RL
# ...         ...        ...     ...       ...
# 63039        -2       0.00     NaN        RL
# 63040        -2       0.00     NaN        RL
# 63041         0       0.00     NaN        RL
# 63042         0       0.00     NaN        RL
# 63043         0       0.00     NaN        RL
#
# [2564 rows x 38 columns]
