# %%
import pandas as pd
import numpy as np

# %%
PATH = "C:\\Users\\User\\Desktop\\blob_storage\\fuel_ampol\\TransactionList.xls"
# pd.read_excel(PATH, engine="xlrd")
df = pd.read_html(PATH, converters={'Card Number' : int, 'Trans. Ref' : int})[0]

# %%
df
# Out:
#        Account       Card Number Registration         Driver Name Trans. Type  \
# 0    600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# 1    600851334  7071340091663061          NaN        SYDNEY WASTE    Purchase
# 2    600851334  7071340092560449          NaN        SYDNEY WASTE    Purchase
# 3    600851334  7071340093858313          NaN        SYDNEY WASTE    Purchase
# 4    600851334  7071340093371952       DYJ57M  STEPHANIE NOMCHONG    Purchase
# ..         ...               ...          ...                 ...         ...
# 245  600851334  7071340093763794          NaN        SYDNEY WASTE    Purchase
# 246  600851334  7071340093858313          NaN        SYDNEY WASTE    Purchase
# 247  600851334  7071340092810406      CMA 32H         SIMON ZIZER    Purchase
# 248  600851334  7071340094111407   SYDNEY WAS        SYDNEY WASTE    Purchase
# 249  600851334  7071340091771773          NaN        SYDNEY WASTE    Purchase
#
# ...

# %%
df.columns
# Out:
# Index(['Account', 'Card Number', 'Registration', 'Driver Name', 'Trans. Type',
#        'Location', 'Trans. Ref', 'Trans. Date', 'Post Date', 'Amount',
#        'Amount Ex GST', 'Location Name'],
#       dtype='object')
